# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(6, activation="relu", input_shape=[6]),
    tf.keras.layers.Dense(6, activation="relu"),
    tf.keras.layers.Dense(6, activation="relu"),
    tf.keras.layers.Dense(6, activation="relu"),
    tf.keras.layers.Dense(6, activation="relu"),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

model_1.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

# model_1.build(input_shape=[None, 6])
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 42
#
#  dense_1 (Dense)             (None, 6)                 42
#
#  dense_2 (Dense)             (None, 6)                 42
#
#  dense_3 (Dense)             (None, 6)                 42
#
#  dense_4 (Dense)             (None, 6)                 42
#
#  dense_5 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 217
# Trainable params: 217
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model_1, show_shapes=True)

# %%
from sklearn.datasets import make_moons

data, labels = make_moons(n_samples=100)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data[:, 0], data[:, 1], c=labels)
plt.xlabel("X-coordinate")
plt.ylabel("Y-coordinate")
plt.title("Moon Dataset")
# Out:
# Text(0.5, 1.0, 'Moon Dataset')

# %% [markdown]
# ## Creating an ML model for the make_moons() dataset

# %%
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(7, activation="relu"),
    tf.keras.layers.Dense(6, activation="relu"),
    tf.keras.layers.Dense(5, activation="relu"),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

model_2.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

# %%
data[:5]
# Out:
# array([[ 1.1595999 , -0.48718178],
#        [ 0.46253829,  0.88659931],
#        [ 1.90096887,  0.06611626],
#        [ 0.19858638, -0.09811053],
#        [ 1.94905575,  0.18489178]])

# %%
labels[:5]
# Out:
# array([1, 0, 1, 1, 1])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((80, 2), (20, 2), (80,), (20,))

# %%
model_2.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 2s 9ms/step - loss: 0.6895 - accuracy: 0.6625
# Epoch 2/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6865 - accuracy: 0.6750
# Epoch 3/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6835 - accuracy: 0.7000
# Epoch 4/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6808 - accuracy: 0.7250
# Epoch 5/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6776 - accuracy: 0.7375
# Epoch 6/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6745 - accuracy: 0.7375
# Epoch 7/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6716 - accuracy: 0.7500
# Epoch 8/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6687 - accuracy: 0.7500
# Epoch 9/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6657 - accuracy: 0.7500
# Epoch 10/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6629 - accuracy: 0.7500
# Epoch 11/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6600 - accuracy: 0.7500
# Epoch 12/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6570 - accuracy: 0.7500
# Epoch 13/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6545 - accuracy: 0.7375
# Epoch 14/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6517 - accuracy: 0.7125
# Epoch 15/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6486 - accuracy: 0.7250
# Epoch 16/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6455 - accuracy: 0.7250
# Epoch 17/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6424 - accuracy: 0.7375
# Epoch 18/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6395 - accuracy: 0.7375
# Epoch 19/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6365 - accuracy: 0.7250
# Epoch 20/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6332 - accuracy: 0.7250
# Epoch 21/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6301 - accuracy: 0.7375
# Epoch 22/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6271 - accuracy: 0.7375
# Epoch 23/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6238 - accuracy: 0.7375
# Epoch 24/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6204 - accuracy: 0.7375
# Epoch 25/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6172 - accuracy: 0.7500
# Epoch 26/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6137 - accuracy: 0.7500
# Epoch 27/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6106 - accuracy: 0.7625
# Epoch 28/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6069 - accuracy: 0.7625
# Epoch 29/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.6034 - accuracy: 0.7625
# Epoch 30/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5999 - accuracy: 0.7750
# Epoch 31/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5961 - accuracy: 0.8000
# Epoch 32/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.5924 - accuracy: 0.8000
# Epoch 33/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.5886 - accuracy: 0.8000
# Epoch 34/100
# 3/3 [==============================] - 0s 10ms/step - loss: 0.5851 - accuracy: 0.8000
# Epoch 35/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5812 - accuracy: 0.8125
# Epoch 36/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.5771 - accuracy: 0.8250
# Epoch 37/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.5733 - accuracy: 0.8250
# Epoch 38/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5690 - accuracy: 0.8250
# Epoch 39/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.5650 - accuracy: 0.8250
# Epoch 40/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5607 - accuracy: 0.8375
# Epoch 41/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5566 - accuracy: 0.8500
# Epoch 42/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5520 - accuracy: 0.8375
# Epoch 43/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5480 - accuracy: 0.8500
# Epoch 44/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5431 - accuracy: 0.8500
# Epoch 45/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5391 - accuracy: 0.9000
# Epoch 46/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5348 - accuracy: 0.9000
# Epoch 47/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5304 - accuracy: 0.9000
# Epoch 48/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5261 - accuracy: 0.9000
# Epoch 49/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5218 - accuracy: 0.9125
# Epoch 50/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5174 - accuracy: 0.9000
# Epoch 51/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5130 - accuracy: 0.9000
# Epoch 52/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5089 - accuracy: 0.9000
# Epoch 53/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.5045 - accuracy: 0.9000
# Epoch 54/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.4999 - accuracy: 0.9000
# Epoch 55/100
# 3/3 [==============================] - 0s 9ms/step - loss: 0.4955 - accuracy: 0.9000
# Epoch 56/100
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4909 - accuracy: 0.9000
# Epoch 57/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4864 - accuracy: 0.8875
# Epoch 58/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4818 - accuracy: 0.8875
# Epoch 59/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4778 - accuracy: 0.8875
# Epoch 60/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4731 - accuracy: 0.8875
# Epoch 61/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4687 - accuracy: 0.8875
# Epoch 62/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4649 - accuracy: 0.8875
# Epoch 63/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4604 - accuracy: 0.8875
# Epoch 64/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4563 - accuracy: 0.8875
# Epoch 65/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4524 - accuracy: 0.8875
# Epoch 66/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.4480 - accuracy: 0.8875
# Epoch 67/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.4434 - accuracy: 0.8875
# Epoch 68/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.4391 - accuracy: 0.8750
# Epoch 69/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4347 - accuracy: 0.8750
# Epoch 70/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4306 - accuracy: 0.8750
# Epoch 71/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4264 - accuracy: 0.8750
# Epoch 72/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4226 - accuracy: 0.8750
# Epoch 73/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4186 - accuracy: 0.8750
# Epoch 74/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.4146 - accuracy: 0.8750
# Epoch 75/100
# 3/3 [==============================] - 0s 8ms/step - loss: 0.4110 - accuracy: 0.8750
# Epoch 76/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4075 - accuracy: 0.8750
# Epoch 77/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4039 - accuracy: 0.8750
# Epoch 78/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4002 - accuracy: 0.8750
# Epoch 79/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3970 - accuracy: 0.8750
# Epoch 80/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3938 - accuracy: 0.8750
# Epoch 81/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3904 - accuracy: 0.8750
# Epoch 82/100
# 3/3 [==============================] - 0s 7ms/step - loss: 0.3873 - accuracy: 0.8750
# Epoch 83/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3839 - accuracy: 0.8750
# Epoch 84/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3810 - accuracy: 0.8750
# Epoch 85/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3778 - accuracy: 0.8750
# Epoch 86/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3748 - accuracy: 0.8750
# Epoch 87/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3717 - accuracy: 0.8750
# Epoch 88/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3692 - accuracy: 0.8750
# Epoch 89/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3658 - accuracy: 0.8750
# Epoch 90/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3631 - accuracy: 0.8750
# Epoch 91/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3604 - accuracy: 0.8750
# Epoch 92/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3577 - accuracy: 0.8750
# Epoch 93/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3548 - accuracy: 0.8750
# Epoch 94/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3525 - accuracy: 0.8750
# Epoch 95/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3497 - accuracy: 0.8875
# Epoch 96/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3472 - accuracy: 0.8750
# Epoch 97/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3449 - accuracy: 0.8750
# Epoch 98/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3424 - accuracy: 0.8750
# Epoch 99/100
# 3/3 [==============================] - 0s 6ms/step - loss: 0.3402 - accuracy: 0.8750
# Epoch 100/100
# 3/3 [==============================] - 0s 5ms/step - loss: 0.3379 - accuracy: 0.8750

# %%
model_2.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 184ms/step - loss: 0.2996 - accuracy: 0.9000
# [0.29962486028671265, 0.8999999761581421]

# %%
from tensorflow.keras.datasets import fashion_mnist

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
